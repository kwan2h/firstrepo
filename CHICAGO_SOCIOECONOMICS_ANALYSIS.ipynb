# %%
# %load_ext sql

# %%
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL
# %sql ibm_db_sa://chx96034:PRhVxjJuxgPWuWpW@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb?security=SSL
# Out:
# 'Connected: chx96034@bludb'

# %%
# type in your query to retrieve list of all tables in the database for your db2 schema (username)
# %sql SELECT * FROM syscat.TABLES
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('SYSIBM  ', 'SYSTABLES', 'SYSIBM  ', 'S', 'T', 'N', None, None, None, None, datetime.datetime(2021, 2, 3, 18, 3, 59, 356402), datetime.datetime(2021, 2, 3, 18, 3, 59, 356402), datetime.datetime(2022, 7, 6, 17, 28, 17, 445870), datetime.datetime(2023, 2, 20, 17, 57, 22, 799259), 83, 5, 0, 11664, 369, 0, 370, -1, -1, -1, 131, 'SYSCATSPACE', None, None, 0, 0, 0, 0, 0, 0, 0, 'N', 'YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY', 0, ' ', '0', -1, 'N', ' ', None, 'R', ' ', 'N', '                                ', None, 'N', ' ', 'F', None, 0, '\x00', 999, 0, 0.0, 545, 0.0, None, 1208, 'SYSIBM', 'IDENTITY', 'SYSIBM', 'IDENTITY', ' ', 0, datetime.datetime(2021, 2, 3, 18, 3, 59, 356402), 0, ' ', None, None, 'N', 'SYSIBM  ', ' ', ' ', ' ', datetime.date(2023, 2, 21), 'R', 'N', 'R', 'N', -1.0, None),
# ...

# %%
# type in your query to retrieve all column names in the CRIME table along with their datatypes and length
# %sql SELECT DISTINCT(name), coltype, length FROM sysibm.syscolumns WHERE tbname = 'CHICAGO_CRIME_DATA'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('ARREST', 'VARCHAR ', 5),
#  ('BEAT', 'SMALLINT', 2),
#  ('BLOCK', 'VARCHAR ', 35),
#  ('CASE_NUMBER', 'VARCHAR ', 8),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('DATE', 'DATE    ', 4),
#  ('DESCRIPTION', 'VARCHAR ', 46),
#  ('DISTRICT', 'SMALLINT', 2),
#  ('DOMESTIC', 'VARCHAR ', 5),
#  ('FBICODE', 'VARCHAR ', 3),
#  ('ID', 'INTEGER ', 4),
#  ('IUCR', 'VARCHAR ', 4),
#  ('LATITUDE', 'DECIMAL ', 18),
#  ('LOCATION', 'VARCHAR ', 29),
#  ('LOCATION_DESCRIPTION', 'VARCHAR ', 33),
#  ('LONGITUDE', 'DECIMAL ', 18),
#  ('PRIMARY_TYPE', 'VARCHAR ', 15),
#  ('WARD', 'SMALLINT', 2),
#  ('X_COORDINATE', 'INTEGER ', 4),
#  ('YEAR', 'SMALLINT', 2),
#  ('Y_COORDINATE', 'INTEGER ', 4)]

# %%
# type in your query to retrieve all column names in the CENSUS table along with their datatypes and length
# %sql SELECT DISTINCT(name), coltype, length FROM sysibm.syscolumns WHERE tbname = 'CENSUS_DATA'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('HARDSHIP_INDEX', 'SMALLINT', 2),
#  ('PERCENT_AGED_16__UNEMPLOYED', 'DECIMAL ', 4),
#  ('PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA', 'DECIMAL ', 4),
#  ('PERCENT_AGED_UNDER_18_OR_OVER_64', 'DECIMAL ', 4),
#  ('PERCENT_HOUSEHOLDS_BELOW_POVERTY', 'DECIMAL ', 4),
#  ('PERCENT_OF_HOUSING_CROWDED', 'DECIMAL ', 4),
#  ('PER_CAPITA_INCOME', 'INTEGER ', 4)]

# %%
# type in your query to retrieve all column names in the CRIME table along with their datatypes and length
# %sql SELECT DISTINCT(name), coltype, length FROM sysibm.syscolumns WHERE tbname = 'CHICAGO_PUBLIC_SCHOOLS'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('10th Grade PLAN (2009)', 'VARCHAR ', 4),
#  ('10th Grade PLAN (2010)', 'VARCHAR ', 4),
#  ('11th Grade Average ACT (2011)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2009)', 'VARCHAR ', 4),
#  ('9th Grade EXPLORE (2010)', 'VARCHAR ', 4),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'VARCHAR ', 3),
#  ('AVERAGE_STUDENT_ATTENDANCE', 'VARCHAR ', 6),
#  ('AVERAGE_TEACHER_ATTENDANCE', 'VARCHAR ', 6),
#  ('CITY', 'VARCHAR ', 7),
#  ('COLLABORATIVE_NAME', 'VARCHAR ', 34),
#  ('COLLEGE_ELIGIBILITY__', 'VARCHAR ', 4),
#  ('COLLEGE_ENROLLMENT', 'SMALLINT', 2),
#  ('COLLEGE_ENROLLMENT_RATE__', 'VARCHAR ', 4),
#  ('COMMUNITY_AREA_NAME', 'VARCHAR ', 22),
#  ('COMMUNITY_AREA_NUMBER', 'SMALLINT', 2),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'VARCHAR ', 15),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'VARCHAR ', 16),
#  ('ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL', 'VARCHAR ', 2),
# ...

# %% [markdown]
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) AS TOTAL_CRIMES FROM CHICAGO_CRIME_DATA
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PER_CAPITA_INCOME FROM CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('West Garfield Park', 10934),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('Riverdale', 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes involving minors.

# %%
# %sql SELECT CASE_NUMBER FROM CHICAGO_CRIME_DATA WHERE LOWER(DESCRIPTION) LIKE '%minor%'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'KIDNAPPING' AND LOWER(DESCRIPTION) LIKE '%child%'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [(5276766, 'HN144152', datetime.date(2007, 1, 26), '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 'FALSE', 'FALSE', 1533, 15, 29, 25, '20', 1143050, 1897546, 2007, Decimal('41.87490841'), Decimal('-87.75024931'), '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5:
# ##### What kind of crimes were recorded at schools?

# %%
# %sql SELECT DISTINCT PRIMARY_TYPE FROM CHICAGO_CRIME_DATA WHERE  LOWER(LOCATION_DESCRIPTION) LIKE '%school%'
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('ASSAULT',),
#  ('BATTERY',),
#  ('CRIMINAL DAMAGE',),
#  ('CRIMINAL TRESPA',),
#  ('NARCOTICS',),
#  ('PUBLIC PEACE VI',)]

# %% [markdown]
# ### Problem 6:
# ##### List the average safety score for all types of schools

# %%
# %sql SELECT ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL SCHOOL_TYPE, AVG(SAFETY_SCORE) AVG_SAFETY_SCORE FROM CHICAGO_PUBLIC_SCHOOLS GROUP BY  ELEMENTARY__MIDDLE__OR_HIGH_SCHOOL
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('ES', 49), ('HS', 49), ('MS', 48)]

# %% [markdown]
# ### Problem 7:
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY FROM CENSUS_DATA ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8:
# ##### Which community area(number) is most crime prone

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS NUMBER_OF_CRIMES FROM CHICAGO_CRIME_DATA GROUP BY COMMUNITY_AREA_NUMBER ORDER BY NUMBER_OF_CRIMES DESC LIMIT 1
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [(25, 43)]

# %% [markdown]
# ### Problem 9:
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT COMMUNITY_AREA_NAME FROM CENSUS_DATA WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA)
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('Riverdale',)]

# %% [markdown]
# ### Problem 10:
# ##### Use a sub-query to determine the Community Area Name with most number of crimes

# %%
# %%sql SELECT COMMUNITY_AREA_NAME FROM CHICAGO_CRIME_DATA CCD, CENSUS_DATA CD
# WHERE CCD.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER AND CCD.COMMUNITY_AREA_NUMBER IN (SELECT COMMUNITY_AREA_NUMBER
# FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# HAVING COUNT(*) = (SELECT MAX(NUM_CRIMES) FROM (
#     SELECT COUNT(*) AS NUM_CRIMES
#     FROM CHICAGO_CRIME_DATA
#     GROUP BY COMMUNITY_AREA_NUMBER) AS CRIME_COUNTS))
# LIMIT 1
# Out:
#  * ibm_db_sa://chx96034:***@54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32733/bludb
# Done.
# [('Austin',)]
